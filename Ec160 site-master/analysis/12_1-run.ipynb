# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("../csv/round2-12_1.csv")

# %%
data.head()
# Out:
#    time  car_id  position  velocity  lane  distance  crashes
# 0     1       0       7.0       1.0     1       7.0        0
# 1     1       1      57.0       1.0     1       7.0        0
# 2     1       2     107.0       1.0     1       7.0        0
# 3     1       3     157.0       1.0     1       7.0        0
# 4     1       4     207.0       1.0     1       7.0        0

# %%
#for i in range(7):
d = data[data.car_id == 5]
plt.plot(d.time, d.velocity, label = str(5))

stops = d[d.velocity == 0]
plt.scatter(stops.time, np.ones(len(stops)), color = "red")

plt.xlabel("Time (s / 10)")
plt.ylabel("Velocity")
plt.legend(loc = "upper right")

# %%
for i in range(0, 7):
    d = data[data.car_id == i]
    plt.plot(d.time[2400:5000], d.distance[2400:5000] + 50 * i, label = str(i))
    plt.plot(d.time[2400:5000], d.distance[2400:5000] + 50 * i + 1000, "--", label = str(i))

t = np.arange(2400, 5000, 10)
p = t * 0.8
#plt.plot(t, p, "x", label = "asymptote")

#plt.legend(loc = "upper left")

# %% [markdown]
# ##### Accidents change behavior
# ##### Drivers coordinates
# #### Behavioral Differences can cause jams
